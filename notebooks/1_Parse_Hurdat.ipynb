# %%
import os
import re
import folium
import pandas as pd
import numpy as np
import datetime
import json
from urllib.request import urlretrieve
from tqdm import tqdm_notebook as tqdm
from mpl_toolkits.basemap import Basemap

# %% [markdown]
# ### 1. Load Data

# %%
def read_hurdat(url, local_fname, location):
    if not os.path.exists(local_fname):
        urlretrieve(url, local_fname)

    records = []
    with open(local_fname,'r') as f:
        for line in f:
            if line.startswith(location):
                record = line.strip()
                reports = []
                records.append((record, reports))
            else:
                reports.append(line.strip())
                
    return records

# %%
url = "https://www.nhc.noaa.gov/data/hurdat/hurdat2-1851-2017-050118.txt"
local_fname = "../data/hurdat2.txt"

records = read_hurdat(url, local_fname, "AL") # AL for atlantic hurricanes

# %%
all_records = get_all_hurricanes(records)
hurricanes_df_raw = create_hurricane_df(all_records)

# %% [markdown]
# ### 2. Parse into Dictionary
# Runs much faster than converting to dataframe
#
# JSON structure will be used for hypothesis analysis

# %%
def convert_lat_lon(value, col):
    """
    Lat/lon is encoded with the numeric value plus E/W/N/S. We want to 
    convert this into an absolute decimal value for maps.
    """
    if col=='lon':
        amount = -float(re.sub('[EW]', '', value)) if 'W' in value else float(re.sub('[EW]', '', value))
    elif col=='lat':
        amount = -float(re.sub('[NS]', '', value)) if 'S' in value else float(re.sub('[NS]', '', value))
    
    return amount

# %%
hurdat_dict = {}

for record in records:
    hurricane_id = record[0].split(',')[0]
    hurricane_name = record[0].split(',')[1].strip()
    
    # add to dict
    hurdat_dict.setdefault(hurricane_id, {'name': hurricane_name})
    hurdat_dict[hurricane_id].setdefault('datapoints', [])
    
    for datapoint in record[1]:
        data_list = [x.strip() for x in datapoint.split(',')]
        datapoint_dict = {'record_date': data_list[0],
                          'time': data_list[1],
                          'storm_status': data_list[3],
                          'lat': convert_lat_lon(data_list[4], 'lat'), 
                          'lon': convert_lat_lon(data_list[5], 'lon'),
                          'max_wind': data_list[6], 
                          'min_pressure': data_list[7]}
        
        hurdat_dict[hurricane_id]['datapoints'].append(datapoint_dict)

# %% [markdown]
# #### Save data

# %%
with open('../data/hurricanes_parsed.json', 'w') as fp:
    json.dump(hurdat_dict, fp)

# %% [markdown]
# ### 3. Feature Engineering for individual storms
# * Indicator if the storm reached hurricane status
# * Whether the storm made landfall
# * How long the storm lasted

# %%
def datapoint_datetime(datapoint):
    """
    For each record, we want a datetime field to calculate
    length of the storm.
    """
    date = datapoint['record_date']
    tm = datapoint['time']
    
    datapoint.setdefault('dt', datetime.datetime.strptime(date+tm, "%Y%m%d%H%M"))
    
    return datapoint

def is_hurricane(storm):
    """
    Did the storm ever make it to hurricane status?
    """
    status_list = []
    for record in storm['datapoints']:
        status_list.append(record['storm_status'])
    
    hurricane = True if 'HU' in status_list else False
    
    return hurricane

def landfall(storm):
    """
    Did the storm make landfall?
    """
    records_on_land = 0
    for record in storm['datapoints']:
        over_land = np.where(bm.is_land(record['lat'], record['lon'])==True, 1, 0)
        records_on_land += over_land
    landfall = True if records_on_land > 0 else False
    
    return landfall

def storm_duration(storm):
    """
    How long did the storm last?
    """
    date_list = []
    for record in storm['datapoints']:
        rec_date = record['dt']
        date_list.append(rec_date)

    duration = max(date_list) - min(date_list)
    
    return duration

# %%
# Apply functions to create features

for key, value in hurdat_dict.items():
    value['is_hurricane'] = is_hurricane(value)
    value['landfall'] = landfall(value)
    value['duration'] = storm_duration(value)
    for record in value['datapoints']:
        record = datapoint_datetime(record)

# %%
maria = hurdat_dict['AL152017']

# %%
maria
# Out:
# {'name': 'MARIA',
#  'datapoints': [{'record_date': '20170916',
#    'time': '1200',
#    'storm_status': 'TD',
#    'lat': 12.2,
#    'lon': -49.7,
#    'max_wind': '30',
#    'min_pressure': '1006',
#    'dt': datetime.datetime(2017, 9, 16, 12, 0)},
#   {'record_date': '20170916',
#    'time': '1800',
#    'storm_status': 'TS',
#    'lat': 12.2,
#    'lon': -51.7,
#    'max_wind': '40',
#    'min_pressure': '1004',
#    'dt': datetime.datetime(2017, 9, 16, 18, 0)},
#   {'record_date': '20170917',
#    'time': '0000',
#    'storm_status': 'TS',
#    'lat': 12.4,
#    'lon': -53.1,
#    'max_wind': '45',
#    'min_pressure': '1002',
#    'dt': datetime.datetime(2017, 9, 17, 0, 0)},
#   {'record_date': '20170917',
#    'time': '0600',
#    'storm_status': 'TS',
#    'lat': 12.8,
#    'lon': -54.4,
#    'max_wind': '55',
#    'min_pressure': '994',
#    'dt': datetime.datetime(2017, 9, 17, 6, 0)},
#   {'record_date': '20170917',
#    'time': '1200',
#    'storm_status': 'TS',
#    'lat': 13.3,
#    'lon': -55.7,
#    'max_wind': '60',
#    'min_pressure': '990',
#    'dt': datetime.datetime(2017, 9, 17, 12, 0)},
#   {'record_date': '20170917',
#    'time': '1800',
#    'storm_status': 'HU',
#    'lat': 13.6,
#    'lon': -57.0,
#    'max_wind': '65',
#    'min_pressure': '986',
#    'dt': datetime.datetime(2017, 9, 17, 18, 0)},
#   {'record_date': '20170918',
#    'time': '0000',
#    'storm_status': 'HU',
#    'lat': 14.0,
#    'lon': -58.0,
#    'max_wind': '75',
#    'min_pressure': '979',
#    'dt': datetime.datetime(2017, 9, 18, 0, 0)},
#   {'record_date': '20170918',
#    'time': '0600',
#    'storm_status': 'HU',
#    'lat': 14.3,
#    'lon': -59.0,
#    'max_wind': '80',
#    'min_pressure': '977',
#    'dt': datetime.datetime(2017, 9, 18, 6, 0)},
#   {'record_date': '20170918',
#    'time': '1200',
#    'storm_status': 'HU',
#    'lat': 14.5,
#    'lon': -59.7,
#    'max_wind': '100',
#    'min_pressure': '967',
#    'dt': datetime.datetime(2017, 9, 18, 12, 0)},
#   {'record_date': '20170918',
#    'time': '1800',
#    'storm_status': 'HU',
#    'lat': 14.9,
#    'lon': -60.4,
#    'max_wind': '110',
#    'min_pressure': '956',
#    'dt': datetime.datetime(2017, 9, 18, 18, 0)},
#   {'record_date': '20170919',
#    'time': '0000',
#    'storm_status': 'HU',
#    'lat': 15.3,
#    'lon': -61.1,
#    'max_wind': '145',
#    'min_pressure': '924',
#    'dt': datetime.datetime(2017, 9, 19, 0, 0)},
#   {'record_date': '20170919',
#    'time': '0115',
#    'storm_status': 'HU',
#    'lat': 15.4,
#    'lon': -61.3,
#    'max_wind': '145',
#    'min_pressure': '922',
#    'dt': datetime.datetime(2017, 9, 19, 1, 15)},
#   {'record_date': '20170919',
#    'time': '0600',
#    'storm_status': 'HU',
#    'lat': 15.7,
#    'lon': -61.9,
#    'max_wind': '135',
#    'min_pressure': '940',
#    'dt': datetime.datetime(2017, 9, 19, 6, 0)},
#   {'record_date': '20170919',
#    'time': '1200',
#    'storm_status': 'HU',
#    'lat': 16.1,
#    'lon': -62.7,
#    'max_wind': '140',
#    'min_pressure': '931',
#    'dt': datetime.datetime(2017, 9, 19, 12, 0)},
#   {'record_date': '20170919',
#    'time': '1800',
#    'storm_status': 'HU',
#    'lat': 16.6,
#    'lon': -63.5,
#    'max_wind': '145',
#    'min_pressure': '920',
#    'dt': datetime.datetime(2017, 9, 19, 18, 0)},
#   {'record_date': '20170920',
#    'time': '0000',
#    'storm_status': 'HU',
#    'lat': 17.0,
#    'lon': -64.3,
#    'max_wind': '150',
#    'min_pressure': '909',
#    'dt': datetime.datetime(2017, 9, 20, 0, 0)},
#   {'record_date': '20170920',
#    'time': '0300',
#    'storm_status': 'HU',
#    'lat': 17.3,
#    'lon': -64.7,
#    'max_wind': '150',
#    'min_pressure': '908',
#    'dt': datetime.datetime(2017, 9, 20, 3, 0)},
#   {'record_date': '20170920',
#    'time': '0600',
#    'storm_status': 'HU',
#    'lat': 17.6,
#    'lon': -65.1,
#    'max_wind': '140',
#    'min_pressure': '913',
#    'dt': datetime.datetime(2017, 9, 20, 6, 0)},
#   {'record_date': '20170920',
#    'time': '1015',
#    'storm_status': 'HU',
#    'lat': 18.0,
#    'lon': -65.9,
#    'max_wind': '135',
#    'min_pressure': '920',
#    'dt': datetime.datetime(2017, 9, 20, 10, 15)},
#   {'record_date': '20170920',
#    'time': '1200',
#    'storm_status': 'HU',
#    'lat': 18.2,
#    'lon': -66.2,
#    'max_wind': '115',
#    'min_pressure': '935',
#    'dt': datetime.datetime(2017, 9, 20, 12, 0)},
#   {'record_date': '20170920',
#    'time': '1800',
#    'storm_status': 'HU',
#    'lat': 18.6,
#    'lon': -67.0,
#    'max_wind': '95',
#    'min_pressure': '959',
#    'dt': datetime.datetime(2017, 9, 20, 18, 0)},
#   {'record_date': '20170921',
#    'time': '0000',
#    'storm_status': 'HU',
#    'lat': 19.0,
#    'lon': -67.6,
#    'max_wind': '95',
#    'min_pressure': '958',
#    'dt': datetime.datetime(2017, 9, 21, 0, 0)},
#   {'record_date': '20170921',
#    'time': '0600',
#    'storm_status': 'HU',
#    'lat': 19.4,
#    'lon': -68.2,
#    'max_wind': '100',
#    'min_pressure': '959',
#    'dt': datetime.datetime(2017, 9, 21, 6, 0)},
#   {'record_date': '20170921',
#    'time': '1200',
#    'storm_status': 'HU',
#    'lat': 19.9,
#    'lon': -68.8,
#    'max_wind': '100',
#    'min_pressure': '959',
#    'dt': datetime.datetime(2017, 9, 21, 12, 0)},
#   {'record_date': '20170921',
#    'time': '1800',
#    'storm_status': 'HU',
#    'lat': 20.5,
#    'lon': -69.5,
#    'max_wind': '105',
#    'min_pressure': '960',
#    'dt': datetime.datetime(2017, 9, 21, 18, 0)},
#   {'record_date': '20170922',
#    'time': '0000',
#    'storm_status': 'HU',
#    'lat': 20.8,
#    'lon': -70.0,
#    'max_wind': '110',
#    'min_pressure': '953',
#    'dt': datetime.datetime(2017, 9, 22, 0, 0)},
#   {'record_date': '20170922',
#    'time': '0600',
#    'storm_status': 'HU',
#    'lat': 21.2,
#    'lon': -70.5,
#    'max_wind': '110',
#    'min_pressure': '959',
#    'dt': datetime.datetime(2017, 9, 22, 6, 0)},
#   {'record_date': '20170922',
#    'time': '1200',
#    'storm_status': 'HU',
#    'lat': 21.9,
#    'lon': -70.9,
#    'max_wind': '110',
#    'min_pressure': '958',
#    'dt': datetime.datetime(2017, 9, 22, 12, 0)},
#   {'record_date': '20170922',
#    'time': '1800',
#    'storm_status': 'HU',
#    'lat': 22.8,
#    'lon': -71.2,
#    'max_wind': '110',
#    'min_pressure': '959',
#    'dt': datetime.datetime(2017, 9, 22, 18, 0)},
#   {'record_date': '20170923',
#    'time': '0000',
#    'storm_status': 'HU',
#    'lat': 23.7,
#    'lon': -71.6,
#    'max_wind': '105',
#    'min_pressure': '953',
#    'dt': datetime.datetime(2017, 9, 23, 0, 0)},
#   {'record_date': '20170923',
#    'time': '0600',
#    'storm_status': 'HU',
#    'lat': 24.4,
#    'lon': -71.9,
#    'max_wind': '100',
#    'min_pressure': '952',
#    'dt': datetime.datetime(2017, 9, 23, 6, 0)},
#   {'record_date': '20170923',
#    'time': '1200',
#    'storm_status': 'HU',
#    'lat': 25.1,
#    'lon': -72.1,
#    'max_wind': '100',
#    'min_pressure': '952',
#    'dt': datetime.datetime(2017, 9, 23, 12, 0)},
#   {'record_date': '20170923',
#    'time': '1800',
#    'storm_status': 'HU',
#    'lat': 25.9,
#    'lon': -72.3,
#    'max_wind': '100',
#    'min_pressure': '952',
#    'dt': datetime.datetime(2017, 9, 23, 18, 0)},
#   {'record_date': '20170924',
#    'time': '0000',
#    'storm_status': 'HU',
#    'lat': 26.6,
#    'lon': -72.4,
#    'max_wind': '100',
#    'min_pressure': '945',
#    'dt': datetime.datetime(2017, 9, 24, 0, 0)},
#   {'record_date': '20170924',
#    'time': '0600',
#    'storm_status': 'HU',
#    'lat': 27.5,
#    'lon': -72.6,
#    'max_wind': '95',
#    'min_pressure': '942',
#    'dt': datetime.datetime(2017, 9, 24, 6, 0)},
#   {'record_date': '20170924',
#    'time': '1200',
#    'storm_status': 'HU',
#    'lat': 28.4,
#    'lon': -72.8,
#    'max_wind': '95',
#    'min_pressure': '947',
#    'dt': datetime.datetime(2017, 9, 24, 12, 0)},
#   {'record_date': '20170924',
#    'time': '1800',
#    'storm_status': 'HU',
#    'lat': 29.1,
#    'lon': -72.9,
#    'max_wind': '90',
#    'min_pressure': '943',
#    'dt': datetime.datetime(2017, 9, 24, 18, 0)},
#   {'record_date': '20170925',
#    'time': '0000',
#    'storm_status': 'HU',
#    'lat': 29.7,
#    'lon': -72.9,
#    'max_wind': '85',
#    'min_pressure': '947',
#    'dt': datetime.datetime(2017, 9, 25, 0, 0)},
#   {'record_date': '20170925',
#    'time': '0600',
#    'storm_status': 'HU',
#    'lat': 30.3,
#    'lon': -72.9,
#    'max_wind': '75',
#    'min_pressure': '954',
#    'dt': datetime.datetime(2017, 9, 25, 6, 0)},
#   {'record_date': '20170925',
#    'time': '1200',
#    'storm_status': 'HU',
#    'lat': 30.8,
#    'lon': -73.0,
#    'max_wind': '70',
#    'min_pressure': '961',
#    'dt': datetime.datetime(2017, 9, 25, 12, 0)},
#   {'record_date': '20170925',
#    'time': '1800',
#    'storm_status': 'HU',
#    'lat': 31.4,
#    'lon': -73.1,
#    'max_wind': '70',
#    'min_pressure': '966',
#    'dt': datetime.datetime(2017, 9, 25, 18, 0)},
#   {'record_date': '20170926',
#    'time': '0000',
#    'storm_status': 'HU',
#    'lat': 32.0,
#    'lon': -73.1,
#    'max_wind': '70',
#    'min_pressure': '966',
#    'dt': datetime.datetime(2017, 9, 26, 0, 0)},
#   {'record_date': '20170926',
#    'time': '0600',
#    'storm_status': 'HU',
#    'lat': 32.6,
#    'lon': -73.1,
#    'max_wind': '65',
#    'min_pressure': '970',
#    'dt': datetime.datetime(2017, 9, 26, 6, 0)},
#   {'record_date': '20170926',
#    'time': '1200',
#    'storm_status': 'HU',
#    'lat': 33.3,
#    'lon': -73.1,
#    'max_wind': '65',
#    'min_pressure': '970',
#    'dt': datetime.datetime(2017, 9, 26, 12, 0)},
#   {'record_date': '20170926',
#    'time': '1800',
#    'storm_status': 'HU',
#    'lat': 33.9,
#    'lon': -73.1,
#    'max_wind': '65',
#    'min_pressure': '975',
#    'dt': datetime.datetime(2017, 9, 26, 18, 0)},
#   {'record_date': '20170927',
#    'time': '0000',
#    'storm_status': 'HU',
#    'lat': 34.4,
#    'lon': -73.0,
#    'max_wind': '65',
#    'min_pressure': '975',
#    'dt': datetime.datetime(2017, 9, 27, 0, 0)},
#   {'record_date': '20170927',
#    'time': '0600',
#    'storm_status': 'HU',
#    'lat': 34.9,
#    'lon': -72.9,
#    'max_wind': '65',
#    'min_pressure': '976',
#    'dt': datetime.datetime(2017, 9, 27, 6, 0)},
#   {'record_date': '20170927',
#    'time': '1200',
#    'storm_status': 'HU',
#    'lat': 35.4,
#    'lon': -72.8,
#    'max_wind': '65',
#    'min_pressure': '977',
#    'dt': datetime.datetime(2017, 9, 27, 12, 0)},
#   {'record_date': '20170927',
#    'time': '1800',
#    'storm_status': 'HU',
#    'lat': 36.0,
#    'lon': -72.6,
#    'max_wind': '65',
#    'min_pressure': '979',
#    'dt': datetime.datetime(2017, 9, 27, 18, 0)},
#   {'record_date': '20170928',
#    'time': '0000',
#    'storm_status': 'HU',
#    'lat': 36.6,
#    'lon': -72.2,
#    'max_wind': '65',
#    'min_pressure': '979',
#    'dt': datetime.datetime(2017, 9, 28, 0, 0)},
#   {'record_date': '20170928',
#    'time': '0600',
#    'storm_status': 'TS',
#    'lat': 36.7,
#    'lon': -71.3,
#    'max_wind': '60',
#    'min_pressure': '982',
#    'dt': datetime.datetime(2017, 9, 28, 6, 0)},
#   {'record_date': '20170928',
#    'time': '1200',
#    'storm_status': 'TS',
#    'lat': 36.8,
#    'lon': -70.0,
#    'max_wind': '60',
#    'min_pressure': '982',
#    'dt': datetime.datetime(2017, 9, 28, 12, 0)},
#   {'record_date': '20170928',
#    'time': '1800',
#    'storm_status': 'TS',
#    'lat': 36.8,
#    'lon': -68.6,
#    'max_wind': '55',
#    'min_pressure': '985',
#    'dt': datetime.datetime(2017, 9, 28, 18, 0)},
#   {'record_date': '20170929',
#    'time': '0000',
#    'storm_status': 'TS',
#    'lat': 36.9,
#    'lon': -66.8,
#    'max_wind': '55',
#    'min_pressure': '985',
#    'dt': datetime.datetime(2017, 9, 29, 0, 0)},
#   {'record_date': '20170929',
#    'time': '0600',
#    'storm_status': 'TS',
#    'lat': 37.0,
#    'lon': -64.6,
#    'max_wind': '50',
#    'min_pressure': '987',
#    'dt': datetime.datetime(2017, 9, 29, 6, 0)},
#   {'record_date': '20170929',
#    'time': '1200',
#    'storm_status': 'TS',
#    'lat': 37.0,
#    'lon': -62.0,
#    'max_wind': '50',
#    'min_pressure': '988',
#    'dt': datetime.datetime(2017, 9, 29, 12, 0)},
#   {'record_date': '20170929',
#    'time': '1800',
#    'storm_status': 'TS',
#    'lat': 37.4,
#    'lon': -59.0,
#    'max_wind': '50',
#    'min_pressure': '988',
#    'dt': datetime.datetime(2017, 9, 29, 18, 0)},
#   {'record_date': '20170930',
#    'time': '0000',
#    'storm_status': 'TS',
#    'lat': 38.1,
#    'lon': -55.6,
#    'max_wind': '50',
#    'min_pressure': '988',
#    'dt': datetime.datetime(2017, 9, 30, 0, 0)},
#   {'record_date': '20170930',
#    'time': '0600',
#    'storm_status': 'TS',
#    'lat': 39.1,
#    'lon': -52.2,
#    'max_wind': '50',
#    'min_pressure': '988',
#    'dt': datetime.datetime(2017, 9, 30, 6, 0)},
#   {'record_date': '20170930',
#    'time': '1200',
#    'storm_status': 'TS',
#    'lat': 40.0,
#    'lon': -48.8,
#    'max_wind': '50',
#    'min_pressure': '988',
#    'dt': datetime.datetime(2017, 9, 30, 12, 0)},
#   {'record_date': '20170930',
#    'time': '1800',
#    'storm_status': 'EX',
#    'lat': 41.2,
#    'lon': -45.6,
#    'max_wind': '45',
#    'min_pressure': '991',
#    'dt': datetime.datetime(2017, 9, 30, 18, 0)},
#   {'record_date': '20171001',
#    'time': '0000',
#    'storm_status': 'EX',
#    'lat': 42.2,
#    'lon': -42.6,
#    'max_wind': '45',
#    'min_pressure': '994',
#    'dt': datetime.datetime(2017, 10, 1, 0, 0)},
#   {'record_date': '20171001',
#    'time': '0600',
#    'storm_status': 'EX',
#    'lat': 43.4,
#    'lon': -39.4,
#    'max_wind': '45',
#    'min_pressure': '996',
#    'dt': datetime.datetime(2017, 10, 1, 6, 0)},
#   {'record_date': '20171001',
#    'time': '1200',
#    'storm_status': 'EX',
#    'lat': 44.9,
#    'lon': -35.5,
#    'max_wind': '45',
#    'min_pressure': '999',
#    'dt': datetime.datetime(2017, 10, 1, 12, 0)},
#   {'record_date': '20171001',
#    'time': '1800',
#    'storm_status': 'EX',
#    'lat': 46.5,
#    'lon': -31.0,
#    'max_wind': '45',
#    'min_pressure': '1003',
#    'dt': datetime.datetime(2017, 10, 1, 18, 0)},
#   {'record_date': '20171002',
#    'time': '0000',
#    'storm_status': 'EX',
#    'lat': 47.5,
#    'lon': -26.5,
#    'max_wind': '40',
#    'min_pressure': '1005',
#    'dt': datetime.datetime(2017, 10, 2, 0, 0)},
#   {'record_date': '20171002',
#    'time': '0600',
#    'storm_status': 'EX',
#    'lat': 48.0,
#    'lon': -22.0,
#    'max_wind': '40',
#    'min_pressure': '1012',
#    'dt': datetime.datetime(2017, 10, 2, 6, 0)},
#   {'record_date': '20171002',
#    'time': '1200',
#    'storm_status': 'EX',
#    'lat': 48.0,
#    'lon': -17.0,
#    'max_wind': '30',
#    'min_pressure': '1016',
#    'dt': datetime.datetime(2017, 10, 2, 12, 0)}],
#  'is_hurricane': True,
#  'landfall': True,
#  'duration': datetime.timedelta(16)}
